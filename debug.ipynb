# %%
import torch
import matplotlib.pyplot as plt

# %%
tp_4_losses = torch.load("./losses_tp4_pp1_dp2.pt")
tp_2_losses = torch.load("./losses_tp2_pp1_dp2.pt")

# tp_4_losses = tp_4_losses.numpy()
# tp_2_losses = tp_2_losses.numpy()

# %%
plt.plot(tp_4_losses, label="tp4_pp1_dp2's losses")
plt.plot(tp_2_losses, label="tp2_pp1_dp2's losses")

# %%
torch.allclose(tp_4_losses[20:], tp_2_losses, rtol=1e-3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 torch.allclose(tp_4_losses[20:], tp_2_losses, rtol=1e-3)
#
# TypeError: allclose(): argument 'input' (position 1) must be Tensor, not numpy.ndarray
